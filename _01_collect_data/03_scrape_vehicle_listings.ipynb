# %%
from find_vehicle_image_urls import *
import datetime as dt
import numpy as np
import pandas as pd

# %%
search_results_df=compile_search_results_df()
search_results_df.head()
# Out:
# File search_results_alfa romeo_4c.csv.csv wrong columns, skipping
# File search_results_porsche_taycan_1739322969.csv wrong columns, skipping
# File search_results_porsche_taycan_1739323122.csv wrong columns, skipping
# File search_results_ford_taurus_1739323840.csv wrong columns, skipping
# File search_results_alfa romeo_4c.csv wrong columns, skipping
# File search_results_hyundai_asgadgadhadhsfqtdhg.csv wrong columns, skipping
# File search_results_ford_lightning_1739323705.csv wrong columns, skipping
# File search_results_porsche_taycan_1739305424.csv wrong columns, skipping
# File search_results_hyundai_ioniq5.csv.csv wrong columns, skipping
# File search_results_alfa-romeo_4c.csv wrong columns, skipping
#                       listing_header  \
# 0       Used 2020 Honda Odyssey EX-L
# 1       Used 2011 Honda Odyssey EX-L
# 2      Used 2024 Honda Odyssey Sport
# 3  Certified 2024 Honda Odyssey EX-L
# 4       Used 2019 Honda Odyssey EX-L
#
#                                                  url  \
# 0  https://www.autotrader.com/cars-for-sale/vehic...
# 1  https://www.autotrader.com/cars-for-sale/vehic...
# 2  https://www.autotrader.com/cars-for-sale/vehic...
# 3  https://www.autotrader.com/cars-for-sale/vehic...
# 4  https://www.autotrader.com/cars-for-sale/vehic...
#
#                                           search_url   make    model  \
# 0  https://www.autotrader.com/cars-for-sale/honda...  honda  odyssey
# 1  https://www.autotrader.com/cars-for-sale/honda...  honda  odyssey
# 2  https://www.autotrader.com/cars-for-sale/honda...  honda  odyssey
# 3  https://www.autotrader.com/cars-for-sale/honda...  honda  odyssey
# 4  https://www.autotrader.com/cars-for-sale/honda...  honda  odyssey
#
#    search_timestamp                        search_metadata  \
# 0        1739360198  {'make': 'honda', 'model': 'odyssey'}
# 1        1739360198  {'make': 'honda', 'model': 'odyssey'}
# 2        1739360198  {'make': 'honda', 'model': 'odyssey'}
# 3        1739360198  {'make': 'honda', 'model': 'odyssey'}
# 4        1739360198  {'make': 'honda', 'model': 'odyssey'}
#
#                                       filename  \
# 0  search_results_honda_odyssey_1739360198.csv
# 1  search_results_honda_odyssey_1739360198.csv
# 2  search_results_honda_odyssey_1739360198.csv
# 3  search_results_honda_odyssey_1739360198.csv
# 4  search_results_honda_odyssey_1739360198.csv
#
#                                            url_clean vehicle_id
# 0  https://www.autotrader.com/cars-for-sale/vehic...  732504624
# 1  https://www.autotrader.com/cars-for-sale/vehic...  738409771
# 2  https://www.autotrader.com/cars-for-sale/vehic...  736531071
# 3  https://www.autotrader.com/cars-for-sale/vehic...  731560875
# 4  https://www.autotrader.com/cars-for-sale/vehic...  736627883

# %%
## let's learn how many vehicle urls are provided by the typical search
print(search_results_df.groupby(['filename']).size().describe())
np.mean(search_results_df.groupby(['filename']).size() >=20)
# Out:
# count    291.000000
# mean      27.756014
# std       10.607687
# min        3.000000
# 25%       29.000000
# 50%       30.000000
# 75%       30.000000
# max      150.000000
# dtype: float64
# 0.9003436426116839

# %%
## dedup (devastating)
n_before = len(search_results_df)
search_results_df=search_results_df.drop_duplicates(subset=['url'])
n_after = len(search_results_df)
message =f'after deduplicating I go from {n_before} to {n_after} records'
print(message)


## let's learn how many vehicle urls are provided by the typical search

print(search_results_df.groupby(['filename']).size().describe())
np.mean(search_results_df.groupby(['filename']).size() >=20)
# Out:
# after deduplicating I go from 8077 to 5372 records
# count    291.000000
# mean      18.460481
# std       14.949143
# min        1.000000
# 25%        4.000000
# 50%       29.000000
# 75%       30.000000
# max      150.000000
# dtype: float64
# 0.5360824742268041

# %%
# df, _ = process_vehicle_webpage(search_results_df['url'][1])

# %%
i=2

search_results_df.loc[i, ]
vehicle_id = search_results_df.loc[i, 'vehicle_id']
filepath=f'{parent_directory_url_csvs}{vehicle_id}.csv'
filepath
already_exist = os.path.exists(filepath)
filepath, already_exist


if already_exist:
    print(f'file {filepath} already exists, skipping')
else:
    df, _ = process_vehicle_webpage(search_results_df.loc[i, 'url_clean'])
# Out:
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/736531071.csv already exists, skipping

# %%
# !ls -lsh ~/Projects/car_classifier/data/autotrader/vehicle_metadata/738409771.csv
# Out:
# 24 -rw-r--r--@ 1 levgolod  staff   9.9K Feb 12 09:09 /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/738409771.csv

# %%
search_results_df = search_results_df.drop_duplicates(subset=['url_clean'])
search_results_df = search_results_df.sample(frac=1)
search_results_df.reset_index(drop=True,inplace=True)
min_sleep=90
sleep = min_sleep+1
# time.sleep(sleep)

for i in search_results_df.index:

    search_results_df.loc[i, ]
    vehicle_id = search_results_df.loc[i, 'vehicle_id']
    url_clean = search_results_df.loc[i, 'url_clean']
    filepath=f'{parent_directory_url_csvs}{vehicle_id}.csv'
    already_exist = os.path.exists(filepath)

    if already_exist:
        print(f'file {filepath} already exists, skipping')
        continue

    message = f'''
###########################################################
### Begin processing {i, vehicle_id} | {dt.datetime.now().replace(microsecond=0)}
###########################################################
    '''
    print(message) # second

    try:
        with timethis(url_clean):
            df, _ = process_vehicle_webpage(url=url_clean, quit=True)

    except Exception as e:
        error_message = traceback.format_exc()
        print(f"notebook 03 - [{url_clean}] Error Traceback:\n", error_message)
        df = pd.DataFrame()

    if len(df)==0:
        sleep += min_sleep
        print(f'due to the cruelty of the gods, sleep param set to {sleep}')
    else:
        sleep -= min_sleep
        sleep = max(sleep, min_sleep)

        # new_sleep = max(min_sleep, sleep-min_sleep)
        # if new_sleep != sleep:
        #     print(f'sleep param set to {new_sleep}')
        #     sleep = new_sleep

    print(f'sleeping {sleep} seconds - starting {dt.datetime.now().replace(second=0, microsecond=0)}')
    time.sleep(sleep)
# Out:
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/739625119.csv already exists, skipping
#
# ###########################################################
# ### Begin processing (1, '734241400') | 2025-03-03 10:04:25
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/734241400]- webpage initiated
#
# year_make_model - success
# list_price - success
# vin - success
# listing_detail - success
# listing_narrative - success
# header image - success
# view_all_media clicked successfully
# the futility is unbearable 29 5
# get_image_urls_from_view_all_media_button - success - 36
# found 37 images
#                                                                    0
# vehicle_image_url  https://images.autotrader.com/scaler/500/375/h...
# vehicle_id                                                 734241400
# url                https://www.autotrader.com/cars-for-sale/vehic...
# vin                                                WBA4J3C51KBL09052
# year_make_model    Used 2019 BMW 430i Gran Coupe xDrive w/ Conven...
# list_price                                                   $19,990
# listing_details    55,766 miles^2.0L 4-Cylinder Turbo Gas Engine^...
# listing_narrative  Vehicle DetailsDiscover luxury and performance...
# saving to /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/734241400.csv
# https://www.autotrader.com/cars-for-sale/vehicle/734241400: 19.835 seconds
# sleeping 90 seconds - starting 2025-03-03 10:04:00
#
# ###########################################################
# ### Begin processing (2, '739759043') | 2025-03-03 10:06:15
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/739759043]- webpage initiated
#
# year_make_model - success
# list_price - success
# vin - success
# listing_detail - success
# listing_narrative - success
# header image - success
# view_all_media clicked successfully
# the futility is unbearable 9 5
# get_image_urls_from_view_all_media_button - success - 11
# found 12 images
#                                                                    0
# vehicle_image_url  https://images.autotrader.com/scaler/500/375/h...
# vehicle_id                                                 739759043
# url                https://www.autotrader.com/cars-for-sale/vehic...
# vin                                                1FTEW1CG7JKC19532
# year_make_model    Used 2018 Ford F150 Lariat w/ Equipment Group ...
# list_price                                                   $28,300
# listing_details    Well-Equipped Vehicle^80,091 miles^- Low Milea...
# listing_narrative  Recent Arrival! CARFAX One-Owner. Carfax Accid...
# saving to /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/739759043.csv
# https://www.autotrader.com/cars-for-sale/vehicle/739759043: 14.333 seconds
# sleeping 90 seconds - starting 2025-03-03 10:06:00
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/738679035.csv already exists, skipping
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/738917066.csv already exists, skipping
#
# ###########################################################
# ### Begin processing (5, '733698506') | 2025-03-03 10:08:00
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/733698506]- webpage initiated
#
# year_make_model - fail
# list_price - fail
# vin - fail
# listing_detail - success
# listing_narrative - success
# header image - fail
# get_image_urls_from_view_all_media_button - fail
# found 0 images
# no images; not saving csv
# https://www.autotrader.com/cars-for-sale/vehicle/733698506: 26.821 seconds
# due to the cruelty of the gods, sleep param set to 180
# sleeping 180 seconds - starting 2025-03-03 10:08:00
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/735235635.csv already exists, skipping
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/730882660.csv already exists, skipping
#
# ###########################################################
# ### Begin processing (8, '723411148') | 2025-03-03 10:11:26
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/723411148]- webpage initiated
#
# year_make_model - fail
# list_price - fail
# vin - fail
# listing_detail - success
# listing_narrative - success
# header image - fail
# get_image_urls_from_view_all_media_button - fail
# found 0 images
# no images; not saving csv
# https://www.autotrader.com/cars-for-sale/vehicle/723411148: 26.471 seconds
# due to the cruelty of the gods, sleep param set to 270
# sleeping 270 seconds - starting 2025-03-03 10:11:00
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/737128671.csv already exists, skipping
#
# ###########################################################
# ### Begin processing (10, '735533826') | 2025-03-03 10:16:23
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/735533826]- webpage initiated
#
# year_make_model - fail
# list_price - fail
# vin - fail
# listing_detail - success
# listing_narrative - success
# header image - fail
# get_image_urls_from_view_all_media_button - fail
# found 0 images
# no images; not saving csv
# https://www.autotrader.com/cars-for-sale/vehicle/735533826: 26.274 seconds
# due to the cruelty of the gods, sleep param set to 360
# sleeping 360 seconds - starting 2025-03-03 10:16:00
#
# ###########################################################
# ### Begin processing (11, '724033747') | 2025-03-03 10:22:49
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/724033747]- webpage initiated
#
# year_make_model - success
# list_price - success
# vin - success
# listing_detail - success
# listing_narrative - success
# header image - success
# view_all_media clicked successfully
# the futility is unbearable 27 5
# get_image_urls_from_view_all_media_button - success - 34
# found 35 images
#                                                                    0
# vehicle_image_url  https://images.autotrader.com/scaler/500/375/h...
# vehicle_id                                                 724033747
# url                https://www.autotrader.com/cars-for-sale/vehic...
# vin                                                JTDT4MCE9MJ079698
# year_make_model                         Used 2021 Toyota Corolla XSE
# list_price                                                   $16,995
# listing_details    102,271 miles^2.0L 4-Cylinder Gas Engine^31 Ci...
# listing_narrative  2021 Toyota Corolla XSE Blizzard Pearl FWD CVT...
# saving to /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/724033747.csv
# https://www.autotrader.com/cars-for-sale/vehicle/724033747: 19.759 seconds
# sleeping 270 seconds - starting 2025-03-03 10:23:00
#
# ###########################################################
# ### Begin processing (12, '738760142') | 2025-03-03 10:27:39
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/738760142]- webpage initiated
#
# year_make_model - fail
# list_price - fail
# vin - fail
# listing_detail - success
# listing_narrative - success
# header image - fail
# get_image_urls_from_view_all_media_button - fail
# found 0 images
# no images; not saving csv
# https://www.autotrader.com/cars-for-sale/vehicle/738760142: 35.114 seconds
# due to the cruelty of the gods, sleep param set to 360
# sleeping 360 seconds - starting 2025-03-03 10:28:00
#
# ###########################################################
# ### Begin processing (13, '739986369') | 2025-03-03 10:34:14
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/739986369]- webpage initiated
#
# year_make_model - success
# list_price - fail
# vin - success
# listing_detail - success
# listing_narrative - success
# header image - success
# view_all_media clicked successfully
# the futility is unbearable 19 5
# get_image_urls_from_view_all_media_button - success - 22
# found 23 images
#                                                                    0
# vehicle_image_url  https://images.autotrader.com/scaler/500/375/h...
# vehicle_id                                                 739986369
# url                https://www.autotrader.com/cars-for-sale/vehic...
# vin                                                WBA63AV01RFT48431
# year_make_model     Used 2024 BMW 430i Gran Coupe w/ Premium Package
# list_price                                                      None
# listing_details    11,094 miles^- Low Mileage^2.0L 4-Cylinder Tur...
# listing_narrative  Welcome to BMW of Lubbock, a Cavender Auto Fam...
# saving to /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/739986369.csv
# https://www.autotrader.com/cars-for-sale/vehicle/739986369: 18.448 seconds
# sleeping 270 seconds - starting 2025-03-03 10:34:00
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/725482594.csv already exists, skipping
#
# ###########################################################
# ### Begin processing (15, '737176888') | 2025-03-03 10:39:03
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/737176888]- webpage initiated
#
# year_make_model - fail
# list_price - fail
# vin - fail
# listing_detail - success
# listing_narrative - success
# header image - fail
# get_image_urls_from_view_all_media_button - fail
# found 0 images
# no images; not saving csv
# https://www.autotrader.com/cars-for-sale/vehicle/737176888: 26.790 seconds
# due to the cruelty of the gods, sleep param set to 360
# sleeping 360 seconds - starting 2025-03-03 10:39:00
#
# ###########################################################
# ### Begin processing (16, '739962483') | 2025-03-03 10:45:29
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/739962483]- webpage initiated
#
# year_make_model - success
# list_price - success
# vin - success
# listing_detail - success
# listing_narrative - success
# header image - success
# view_all_media clicked successfully
# the futility is unbearable 22 5
# get_image_urls_from_view_all_media_button - success - 27
# found 28 images
#                                                                    0
# vehicle_image_url  https://images.autotrader.com/scaler/500/375/h...
# vehicle_id                                                 739962483
# url                https://www.autotrader.com/cars-for-sale/vehic...
# vin                                                JTDAAAAF6P3012866
# year_make_model                           Used 2023 Toyota Crown XLE
# list_price                                                   $32,748
# listing_details    26,300 miles^Hybrid: Gas/Electric^Information ...
# listing_narrative  CARFAX One-Owner. Black 2023 Toyota Crown XLE ...
# saving to /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/739962483.csv
# https://www.autotrader.com/cars-for-sale/vehicle/739962483: 20.658 seconds
# sleeping 270 seconds - starting 2025-03-03 10:45:00
#
# ###########################################################
# ### Begin processing (17, '739430207') | 2025-03-03 10:50:20
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/739430207]- webpage initiated
#
# year_make_model - fail
# list_price - fail
# vin - fail
# listing_detail - success
# listing_narrative - success
# header image - fail
# get_image_urls_from_view_all_media_button - fail
# found 0 images
# no images; not saving csv
# https://www.autotrader.com/cars-for-sale/vehicle/739430207: 26.499 seconds
# due to the cruelty of the gods, sleep param set to 360
# sleeping 360 seconds - starting 2025-03-03 10:50:00
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/734538897.csv already exists, skipping
#
# ###########################################################
# ### Begin processing (19, '737819523') | 2025-03-03 10:56:47
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/737819523]- webpage initiated
#
# year_make_model - fail
# list_price - fail
# vin - fail
# listing_detail - success
# listing_narrative - fail
# header image - fail
# get_image_urls_from_view_all_media_button - fail
# found 0 images
# no images; not saving csv
# https://www.autotrader.com/cars-for-sale/vehicle/737819523: 31.222 seconds
# due to the cruelty of the gods, sleep param set to 450
# sleeping 450 seconds - starting 2025-03-03 10:57:00
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/738685564.csv already exists, skipping
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/724975920.csv already exists, skipping
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/735616518.csv already exists, skipping
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/739806934.csv already exists, skipping
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/731519617.csv already exists, skipping
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/736681788.csv already exists, skipping
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/737904358.csv already exists, skipping
#
# ###########################################################
# ### Begin processing (27, '736060186') | 2025-03-03 11:04:48
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/736060186]- webpage initiated
#
# year_make_model - fail
# list_price - fail
# vin - fail
# listing_detail - success
# listing_narrative - fail
# header image - fail
# get_image_urls_from_view_all_media_button - fail
# found 0 images
# no images; not saving csv
# https://www.autotrader.com/cars-for-sale/vehicle/736060186: 30.167 seconds
# due to the cruelty of the gods, sleep param set to 540
# sleeping 540 seconds - starting 2025-03-03 11:05:00
# file /Users/levgolod/Projects/car_classifier/data/autotrader/vehicle_metadata/736835937.csv already exists, skipping
#
# ###########################################################
# ### Begin processing (29, '739867745') | 2025-03-03 11:14:18
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/739867745]- webpage initiated
#
# year_make_model - fail
# list_price - fail
# vin - fail
# listing_detail - fail
# listing_narrative - fail
# header image - fail
# get_image_urls_from_view_all_media_button - fail
# found 0 images
# no images; not saving csv
# https://www.autotrader.com/cars-for-sale/vehicle/739867745: 32.940 seconds
# due to the cruelty of the gods, sleep param set to 630
# sleeping 630 seconds - starting 2025-03-03 11:14:00
#
# ###########################################################
# ### Begin processing (30, '739536182') | 2025-03-03 11:25:21
# ###########################################################
#
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/739536182]- webpage initiated
#
# year_make_model - fail
# list_price - fail
# vin - fail
# listing_detail - success
# listing_narrative - success
# header image - fail
# get_image_urls_from_view_all_media_button - fail
# found 0 images
# no images; not saving csv
# https://www.autotrader.com/cars-for-sale/vehicle/739536182: 27.871 seconds
# due to the cruelty of the gods, sleep param set to 720
# sleeping 720 seconds - starting 2025-03-03 11:25:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 49
#      43     # new_sleep = max(min_sleep, sleep-min_sleep)
#      44     # if new_sleep != sleep:
#      45     #     print(f'sleep param set to {new_sleep}')
#      46     #     sleep = new_sleep
#      48 print(f'sleeping {sleep} seconds - starting {dt.datetime.now().replace(second=0, microsecond=0)}')
# ---> 49 time.sleep(sleep)
#
# KeyboardInterrupt:

# %%
# single vehicle listing [https://www.autotrader.com/cars-for-sale/vehicle/730197477]- webpage initiated
#     only  4 images?

# socket.timeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/levgolod/Projects/car_classifier/find_vehicle_image_urls.py", line 273, in process_vehicle_webpage
#     driver.get(url_cleaned)
#   File "/Users/levgolod/Projects/venv3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py", line 393, in get
#     self.execute(Command.GET, {"url": url})
#   File "/Users/levgolod/Projects/venv3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py", line 382, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/Users/levgolod/Projects/venv3/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py", line 404, in execute

# %%
process_vehicle_webpage [https://www.autotrader.com/cars-for-sale/vehicle/722919380] Error Traceback:
 Traceback (most recent call last):
  File "/Users/levgolod/Projects/car_classifier/find_vehicle_image_urls.py", line 433, in process_vehicle_webpage
    image_urls = get_image_urls_from_view_all_media_button(driver)
  File "/Users/levgolod/Projects/car_classifier/find_vehicle_image_urls.py", line 309, in get_image_urls_from_view_all_media_button
    driver.execute_script(f"arguments[0].scrollTop += {scroll_distance};", scroll_panel)
  File "/Users/levgolod/Projects/venv3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py", line 444, in execute_script
    return self.execute(command, {"script": script, "args": converted_args})["value"]
  File "/Users/levgolod/Projects/venv3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py", line 384, in execute
    self.error_handler.check_response(response)
  File "/Users/levgolod/Projects/venv3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py", line 232, in check_response

# %%
# https://www.autotrader.com/cars-for-sale/vehicle/737396206
# only 1 image captured?
# in these instances should maybe try again
